# %% [markdown]
# <a href="https://colab.research.google.com/github/rifat-mukul/Python-ML-Toolkit/blob/main/splittingData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt

# %%
data = load_iris()

# %%
x, y = data.data, data.target

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
count = np.bincount(y_test)
position = np.arange(3)

plt.bar(position, count, align='center')
plt.xticks(position,data.target_names)
# Out:
# ([<matplotlib.axis.XTick at 0x7b86342afb00>,
# ...
#  [Text(0, 0, 'setosa'), Text(1, 0, 'versicolor'), Text(2, 0, 'virginica')])

# %%
len(x_train)
# Out:
# 120

# %%
len(x)
# Out:
# 150

# %%
from sklearn.model_selection import  StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

# %%
print(split)
# Out:
# StratifiedShuffleSplit(n_splits=1, random_state=42, test_size=0.2,
#             train_size=None)

# %%
for train_index, test_index in split.split(x, y):
    x_train, x_test = x[train_index], x[test_index]
    y_train, y_test = y[train_index], y[test_index]

# %%
count = np.bincount(y_test)
position = np.arange(3)

plt.bar(position, count, align='center')
plt.xticks(position,data.target_names)
# Out:
# ([<matplotlib.axis.XTick at 0x7b8602eb7b00>,
# ...
#  [Text(0, 0, 'setosa'), Text(1, 0, 'versicolor'), Text(2, 0, 'virginica')])
